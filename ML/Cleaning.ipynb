# %%
# Importing the necessary modules

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
# Reading the given data by Kaggle 
# (Anna Montoya, DataCanary. (2016). House Prices - 
# Advanced Regression Techniques. Kaggle. https://kaggle.com/competitions/house-prices-advanced-regression-techniques)

df_train = pd.read_csv("C:/Bansal Data/Drishti Data/Self/VS code/Kaggle/Home Prices/Data/train.csv").drop("Id", axis = 1)
df_test = pd.read_csv("C:/Bansal Data/Drishti Data/Self/VS code/Kaggle/Home Prices/Data/test.csv").drop("Id", axis = 1)

df_train.tail(5)

# Note: Dropping the ID for both train and test files so that they can be combined with the right variables.
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 1455          60       RL         62.0     7917   Pave   NaN      Reg
# 1456          20       RL         85.0    13175   Pave   NaN      Reg
# 1457          70       RL         66.0     9042   Pave   NaN      Reg
# 1458          20       RL         68.0     9717   Pave   NaN      Reg
# 1459          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig  ... PoolArea PoolQC  Fence MiscFeature  \
# 1455         Lvl    AllPub    Inside  ...        0    NaN    NaN         NaN
# 1456         Lvl    AllPub    Inside  ...        0    NaN  MnPrv         NaN
# 1457         Lvl    AllPub    Inside  ...        0    NaN  GdPrv        Shed
# 1458         Lvl    AllPub    Inside  ...        0    NaN    NaN         NaN
# 1459         Lvl    AllPub    Inside  ...        0    NaN    NaN         NaN
#
#      MiscVal MoSold  YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
df_test.head(5)
# Out:
#    MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0          20       RH         80.0    11622   Pave   NaN      Reg
# 1          20       RL         81.0    14267   Pave   NaN      IR1
# 2          60       RL         74.0    13830   Pave   NaN      IR1
# 3          60       RL         78.0     9978   Pave   NaN      IR1
# 4         120       RL         43.0     5005   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig  ... ScreenPorch PoolArea PoolQC  Fence  \
# 0         Lvl    AllPub    Inside  ...         120        0    NaN  MnPrv
# 1         Lvl    AllPub    Corner  ...           0        0    NaN    NaN
# 2         Lvl    AllPub    Inside  ...           0        0    NaN  MnPrv
# 3         Lvl    AllPub    Inside  ...           0        0    NaN    NaN
# 4         HLS    AllPub    Inside  ...         144        0    NaN    NaN
#
#   MiscFeature MiscVal  MoSold  YrSold  SaleType  SaleCondition
# ...

# %%
print("The number of rows and columns for train.csv:", df_train.shape)
print("The number of rows and columns for test.csv:", df_test.shape)
# Out:
# The number of rows and columns for train.csv: (1460, 80)
# The number of rows and columns for test.csv: (1459, 79)
# The number of rows and columns for sample_submission.csv: (1459, 2)

# %%
df_train.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %%
print('Which column does test data have that is not in train data?:', set(df_train.columns).difference(set(df_test.columns)))
# Out:
# Which column does test data have that is not in train data?: {'SalePrice'}

# %%
Null_train = df_train.isnull().sum().sort_values(ascending = False).to_frame('Null_entries')
Null_train = Null_train[Null_train.Null_entries > 0]
Null_train
# Out:
#               Null_entries
# PoolQC                1453
# MiscFeature           1406
# Alley                 1369
# Fence                 1179
# MasVnrType             872
# FireplaceQu            690
# LotFrontage            259
# GarageYrBlt             81
# GarageCond              81
# GarageType              81
# GarageFinish            81
# GarageQual              81
# BsmtExposure            38
# BsmtFinType2            38
# BsmtCond                37
# BsmtQual                37
# BsmtFinType1            37
# MasVnrArea               8
# Electrical               1

# %%
# defining a function for making copy of data.

def data(df_train, df_test):
    df1, df2 = df_train.copy(), df_test.copy()
    df1["group"] = "df_train"
    df2["group"] = "df_test"

    return pd.concat([df1, df2], axis = 0, ignore_index = True)

data = data(df_train, df_test)
data.head(5)
# Out:
#    MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0          60       RL         65.0     8450   Pave   NaN      Reg
# 1          20       RL         80.0     9600   Pave   NaN      Reg
# 2          60       RL         68.0    11250   Pave   NaN      IR1
# 3          70       RL         60.0     9550   Pave   NaN      IR1
# 4          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig  ... PoolQC Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub    Inside  ...    NaN   NaN         NaN       0
# 1         Lvl    AllPub       FR2  ...    NaN   NaN         NaN       0
# 2         Lvl    AllPub    Inside  ...    NaN   NaN         NaN       0
# 3         Lvl    AllPub    Corner  ...    NaN   NaN         NaN       0
# 4         Lvl    AllPub       FR2  ...    NaN   NaN         NaN       0
#
#   MoSold YrSold  SaleType  SaleCondition  SalePrice     group
# 0      2   2008        WD         Normal   208500.0  df_train
# ...

# %%
# defining a function that takes two parameters: a dataframe and an ordinal threshold.

def ColDataTypes(data, ord):
    numerical = data.select_dtypes("number").columns.to_list()
    categorical = data.select_dtypes("object").columns.to_list()

    # identifies columns with a unique value count less than the 
    # specified threshold (ord) from the numeric columns. 
    # These are considered as potential ordinal columns.
    ordinals = [col for col in numerical if data[col].nunique() < ord]

    # Updating the list of numeric columns by excluding the identified ordinal columns.
    numerical = [col for col in numerical if col not in ordinals]
    return numerical, ordinals, categorical

numerical, ordinals, categorical = ColDataTypes(df_test, 20)

print(f"Columns list for Numericals: {numerical}", end = "\n\n")
print(f"Columns list for Categoricals: {categorical}", end = "\n\n")
print(f"Columns list for Ordinals: {ordinals}", end = "\n\n")
# Out:
# Columns list for Numericals: ['LotFrontage', 'LotArea', 'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'GrLivArea', 'GarageYrBlt', 'GarageArea', 'WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch', 'ScreenPorch', 'MiscVal']
#
# Columns list for Categoricals: ['MSZoning', 'Street', 'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2', 'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual', 'Functional', 'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual', 'GarageCond', 'PavedDrive', 'PoolQC', 'Fence', 'MiscFeature', 'SaleType', 'SaleCondition']
#
# ...

# %%
print("The number of rows and columns for the whole data:", data.shape)
# Out:
# The number of rows and columns for the whole data: (2919, 81)

# %%
df_train.duplicated().sum()
# Out:
# 0

# %%
# %pip install --upgrade tensorflow
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2 -> 23.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import tensorflow as tf                                            #2.15.0 version
import tensorflow_decision_forests as tfdf                         #1.8.1 version
print("TensorFlow v" + tf.__version__)
print("TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# WARNING:root:TensorFlow Decision Forests 1.8.1 is compatible with the following TensorFlow Versions: ['2.15.0']. However, TensorFlow 2.13.0 was detected. This can cause issues with the TF API and symbols in the custom C++ ops. See the TF and TF-DF compatibility table at https://github.com/tensorflow/decision-forests/blob/main/documentation/known_issues.md#compatibility-table.
# WARNING:root:Failure to load the inference.so custom c++ tensorflow ops. This error is likely caused the version of TensorFlow and TensorFlow Decision Forests are not compatible. Full error:c:\Users\dbansal\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow_decision_forests\tensorflow\ops\inference\inference.so not found
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# c:\Bansal Data\Drishti Data\Self\VS code\Kaggle\Home Prices\Cleaning.ipynb Cell 13 line 2
# ...
